# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
cd = pd.read_excel("/content/Classroom Data 1-2023-04-18-10-19-22.xlsx", skiprows=8)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# # New Section

# %%
cd.head()
# Out:
#    Unnamed: 0 Contact Name Unnamed: 2 Contact: Gender  LMS Id  \
# 0         NaN    Sam Ngigi        NaN            Male     NaN
# 1         NaN    Sam Ngigi        NaN            Male     NaN
# 2         NaN    Sam Ngigi        NaN            Male     NaN
# 3         NaN    Sam Ngigi        NaN            Male     NaN
# 4         NaN    Sam Ngigi        NaN            Male     NaN
#
#   Course Connection: Course Connection ID Course Offering Name  \
# 0                                CC-49364                  NaN
# 1                                CC-49361                  NaN
# 2                                CC-56027                  NaN
# 3                                CC-56026                  NaN
# 4                                CC-56025                  NaN
#
#   Course Offering ID Course Offering Start Date Course End Date  \
# 0                NaN                        NaN             NaN
# 1                NaN                        NaN             NaN
# ...

# %%
cd.tail()
# Out:
#        Unnamed: 0     Contact Name Unnamed: 2 Contact: Gender   LMS Id  \
# 26924         NaN  Japheth Mualuko        NaN            Male  26344.0
# 26925         NaN    Ahmed Ibrahim        NaN            Male  26345.0
# 26926         NaN            Total        Sum             NaN      NaN
# 26927         NaN              NaN     Unique             NaN      NaN
# 26928         NaN              NaN      Count           26926      NaN
#
#       Course Connection: Course Connection ID Course Offering Name  \
# 26924                                CC-15085            WVPowerBI
# 26925                                CC-15081            WVPowerBI
# 26926                                     NaN                  NaN
# 26927                                     NaN                  448
# 26928                                     NaN                  NaN
#
#       Course Offering ID Course Offering Start Date Course End Date  \
# ...

# %%
# Removing unnamed columns
cd = cd.loc[:, ~cd.columns.str.contains("^Unnamed")]
cd.head()
# Out:
#   Contact Name Contact: Gender  LMS Id  \
# 0    Sam Ngigi            Male     NaN
# 1    Sam Ngigi            Male     NaN
# 2    Sam Ngigi            Male     NaN
# 3    Sam Ngigi            Male     NaN
# 4    Sam Ngigi            Male     NaN
#
#   Course Connection: Course Connection ID Course Offering Name  \
# 0                                CC-49364                  NaN
# 1                                CC-49361                  NaN
# 2                                CC-56027                  NaN
# 3                                CC-56026                  NaN
# 4                                CC-56025                  NaN
#
#   Course Offering ID Course Offering Start Date Course End Date  \
# 0                NaN                        NaN             NaN
# 1                NaN                        NaN             NaN
# 2                NaN                        NaN             NaN
# 3                NaN                        NaN             NaN
# ...

# %%
# Find null values
cd.isnull().sum()/len(cd)*100
# Out:
# Contact Name                                0.007427
# Contact: Gender                             3.275279
# LMS Id                                      1.552230
# Course Connection: Course Connection ID     0.011140
# Course Offering Name                        0.066842
# Course Offering ID                          0.070556
# Course Offering Start Date                  0.070556
# Course End Date                             1.180883
# Attendance Score                           36.299157
# IP Grade Average                           18.567344
# Total Canvas Hours                          8.912325
# Contact: Student Overall NPS               19.161499
# Contact: Student SIS ID                     0.011140
# Contact: Contact ID                         0.011140
# Course Term                                 0.627576
# dtype: float64

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26929 entries, 0 to 26928
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contact Name                             26927 non-null  object
#  1   Contact: Gender                          26047 non-null  object
#  2   LMS Id                                   26511 non-null  float64
#  3   Course Connection: Course Connection ID  26926 non-null  object
#  4   Course Offering Name                     26911 non-null  object
#  5   Course Offering ID                       26910 non-null  object
#  6   Course Offering Start Date               26910 non-null  object
#  7   Course End Date                          26611 non-null  object
#  8   Attendance Score                         17154 non-null  float64
#  9   IP Grade Average                         21929 non-null  float64
# ...

# %%
cd = cd.dropna(subset=["IP Grade Average", "Attendance Score", "Total Canvas Hours"] )
cd.head()
# Out:
#       Contact Name Contact: Gender   LMS Id  \
# 16    Emma Gachoki          Female  35796.0
# 17  Evelyne Mwende          Female  35798.0
# 18   Jerry Auvagha            Male  35799.0
# 19    Peter Gakure            Male  35792.0
# 20    Micah Ledama            Male  35801.0
#
#    Course Connection: Course Connection ID Course Offering Name  \
# 16                                CC-50732          B2CDevOps01
# 17                                CC-50749          B2CDevOps01
# 18                                CC-50727          B2CDevOps01
# 19                                CC-50755          B2CDevOps01
# 20                                CC-50739          B2CDevOps01
#
#    Course Offering ID Course Offering Start Date Course End Date  \
# 16        B2CDevOps01                 14/11/2022      20/01/2023
# 17        B2CDevOps01                 14/11/2022      20/01/2023
# 18        B2CDevOps01                 14/11/2022      20/01/2023
# ...

# %%
# Find null values
cd.isnull().sum()/len(cd)*100
# Out:
# Contact Name                                0.000000
# Contact: Gender                             0.633573
# LMS Id                                      0.006532
# Course Connection: Course Connection ID     0.006532
# Course Offering Name                        0.006532
# Course Offering ID                          0.006532
# Course Offering Start Date                  0.006532
# Course End Date                             1.534944
# Attendance Score                            0.000000
# IP Grade Average                            0.000000
# Total Canvas Hours                          0.000000
# Contact: Student Overall NPS               10.013063
# Contact: Student SIS ID                     0.006532
# Contact: Contact ID                         0.006532
# Course Term                                 0.875245
# dtype: float64

# %%
cd = cd.dropna()
cd.head()
# Out:
#       Contact Name Contact: Gender   LMS Id  \
# 16    Emma Gachoki          Female  35796.0
# 17  Evelyne Mwende          Female  35798.0
# 18   Jerry Auvagha            Male  35799.0
# 19    Peter Gakure            Male  35792.0
# 21    Felix Kinaro            Male  35802.0
#
#    Course Connection: Course Connection ID Course Offering Name  \
# 16                                CC-50732          B2CDevOps01
# 17                                CC-50749          B2CDevOps01
# 18                                CC-50727          B2CDevOps01
# 19                                CC-50755          B2CDevOps01
# 21                                CC-50738          B2CDevOps01
#
#    Course Offering ID Course Offering Start Date Course End Date  \
# 16        B2CDevOps01                 14/11/2022      20/01/2023
# 17        B2CDevOps01                 14/11/2022      20/01/2023
# 18        B2CDevOps01                 14/11/2022      20/01/2023
# ...

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13529 entries, 16 to 26920
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contact Name                             13529 non-null  object
#  1   Contact: Gender                          13529 non-null  object
#  2   LMS Id                                   13529 non-null  float64
#  3   Course Connection: Course Connection ID  13529 non-null  object
#  4   Course Offering Name                     13529 non-null  object
#  5   Course Offering ID                       13529 non-null  object
#  6   Course Offering Start Date               13529 non-null  object
#  7   Course End Date                          13529 non-null  object
#  8   Attendance Score                         13529 non-null  float64
#  9   IP Grade Average                         13529 non-null  float64
# ...

# %%
# check duplicates

cd.duplicated().sum()
# Out:
# 0

# %%
ad = pd.read_excel ("/content/New Applications with Applicant Report-2023-04-18-10-22-13.xlsx", skiprows=8)
ad.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Unnamed: 0 Application: Application Name Unnamed: 2 Applicant: Last Name  \
# 0         NaN                      APP-1984        NaN                 Juma
# 1         NaN                      APP-1631        NaN             Kang'Ara
# 2         NaN                      APP-1091        NaN                 Abdi
# 3         NaN                      APP-1331        NaN                 Abdi
# 4         NaN                      APP-0267        NaN              Mwaniki
#
#   Applicant: Contact ID Date of Birth How you heard about Moringa School  \
# 0       0034K00000AApvK           NaN             Moringa School Website
# 1       0034K0000081eSu           NaN                           Facebook
# 2       0034K000009yIC5           NaN           Alumni of Moringa School
# ...

# %%
# Removing unnamed columns
ad = ad.loc[:, ~ad.columns.str.contains("^Unnamed")]
ad.head()
# Out:
#   Application: Application Name Applicant: Last Name Applicant: Contact ID  \
# 0                      APP-1984                 Juma       0034K00000AApvK
# 1                      APP-1631             Kang'Ara       0034K0000081eSu
# 2                      APP-1091                 Abdi       0034K000009yIC5
# 3                      APP-1331                 Abdi       0034K000009yIC5
# 4                      APP-0267              Mwaniki       0034K000009yICH
#
#   Date of Birth How you heard about Moringa School  \
# 0           NaN             Moringa School Website
# 1           NaN                           Facebook
# 2           NaN           Alumni of Moringa School
# 3           NaN                           Referral
# 4           NaN             Moringa School Website
#
#   Knows how to install an Operating System Applicant: Current Term (Class)  \
# 0                                      NaN                            SD38
# ...

# %%
ad.isnull().sum()/len(ad) *100
# Out:
# Application: Application Name                            0.006337
# Applicant: Last Name                                     0.006337
# Applicant: Contact ID                                    0.012673
# Date of Birth                                           74.558013
# How you heard about Moringa School                       8.225081
# Knows how to install an Operating System                91.850960
# Applicant: Current Term (Class)                         79.728788
# Applicant: Intake Class                                 31.442874
# Applicant: Email                                         0.019010
# Interview Score                                         99.486725
# Completed high school                                   54.122045
# Applying To                                             15.499651
# Inspiration to Apply                                    19.212978
# Mode of Internet Access                                 91.831950
# ...

# %%
ad.head(2)
# Out:
#   Application: Application Name Applicant: Last Name Applicant: Contact ID  \
# 0                      APP-1984                 Juma       0034K00000AApvK
# 1                      APP-1631             Kang'Ara       0034K0000081eSu
#
#   Date of Birth How you heard about Moringa School  \
# 0           NaN             Moringa School Website
# 1           NaN                           Facebook
#
#   Knows how to install an Operating System Applicant: Current Term (Class)  \
# 0                                      NaN                            SD38
# 1                                      NaN                            SD38
#
#   Applicant: Intake Class          Applicant: Email  Interview Score  ...  \
# 0           DevopsB2C02-B   vincentjuma64@gmail.com              NaN  ...
# 1                     NaN  carolkangara30@gmail.com              NaN  ...
#
#   Applicant: Age Applicant: Primary Academic Level  \
# 0           29.0                               NaN
# ...

# %%
cd.head(2)
# Out:
#       Contact Name Contact: Gender   LMS Id  \
# 16    Emma Gachoki          Female  35796.0
# 17  Evelyne Mwende          Female  35798.0
#
#    Course Connection: Course Connection ID Course Offering Name  \
# 16                                CC-50732          B2CDevOps01
# 17                                CC-50749          B2CDevOps01
#
#    Course Offering ID Course Offering Start Date Course End Date  \
# 16        B2CDevOps01                 14/11/2022      20/01/2023
# 17        B2CDevOps01                 14/11/2022      20/01/2023
#
#     Attendance Score  IP Grade Average  Total Canvas Hours  \
# 16             100.0          0.891675              367.66
# 17             100.0          0.966675              148.24
#
#     Contact: Student Overall NPS Contact: Student SIS ID Contact: Contact ID  \
# 16                           0.0                fUFZbQAO     0034K00000fUFZb
# 17                           0.0                fUFZcQAO     0034K00000fUFZc
#
#     Course Term
# ...

# %%
cd["Contact: Contact ID"].nunique()
# Out:
# 3972

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13529 entries, 16 to 26920
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contact Name                             13529 non-null  object
#  1   Contact: Gender                          13529 non-null  object
#  2   LMS Id                                   13529 non-null  float64
#  3   Course Connection: Course Connection ID  13529 non-null  object
#  4   Course Offering Name                     13529 non-null  object
#  5   Course Offering ID                       13529 non-null  object
#  6   Course Offering Start Date               13529 non-null  object
#  7   Course End Date                          13529 non-null  object
#  8   Attendance Score                         13529 non-null  float64
#  9   IP Grade Average                         13529 non-null  float64
# ...

# %%
ad=ad.dropna(subset=['Highest education level completed','Applicant Conversion Probability', 'Applicant: Contact ID'  ])
ad.head()
# Out:
#   Application: Application Name Applicant: Last Name Applicant: Contact ID  \
# 0                      APP-1984                 Juma       0034K00000AApvK
# 1                      APP-1631             Kang'Ara       0034K0000081eSu
# 2                      APP-1091                 Abdi       0034K000009yIC5
# 3                      APP-1331                 Abdi       0034K000009yIC5
# 4                      APP-0267              Mwaniki       0034K000009yICH
#
#   Date of Birth How you heard about Moringa School  \
# 0           NaN             Moringa School Website
# 1           NaN                           Facebook
# 2           NaN           Alumni of Moringa School
# 3           NaN                           Referral
# 4           NaN             Moringa School Website
#
#   Knows how to install an Operating System Applicant: Current Term (Class)  \
# 0                                      NaN                            SD38
# ...

# %%
newad=ad[['Highest education level completed','Applicant Conversion Probability', 'Applicant: Contact ID'  ]]
newad.head()
# Out:
#   Highest education level completed  Applicant Conversion Probability  \
# 0                  Bachelors Degree                              20.0
# 1                           Diploma                             100.0
# 2                           Diploma                             100.0
# 3                           Diploma                             100.0
# 4                  Bachelors Degree                             100.0
#
#   Applicant: Contact ID
# 0       0034K00000AApvK
# 1       0034K0000081eSu
# 2       0034K000009yIC5
# 3       0034K000009yIC5
# 4       0034K000009yICH

# %%
df=cd.merge(newad, left_on="Contact: Contact ID", right_on="Applicant: Contact ID", how="inner")
df.head()
# Out:
#         Contact Name Contact: Gender   LMS Id  \
# 0      Rodney Kabiru            Male  35797.0
# 1     Jeffery Omondi            Male  35800.0
# 2     Jeffery Omondi            Male  35800.0
# 3  Maamun Bwanakombo            Male     63.0
# 4       Sandra Metto          Female     47.0
#
#   Course Connection: Course Connection ID Course Offering Name  \
# 0                                CC-50735          B2CDevOps01
# 1                                CC-50753          B2CDevOps01
# 2                                CC-50753          B2CDevOps01
# 3                                CC-58097          B2CDevOps02
# 4                                CC-58105          B2CDevOps02
#
#   Course Offering ID Course Offering Start Date Course End Date  \
# 0        B2CDevOps01                 14/11/2022      20/01/2023
# 1        B2CDevOps01                 14/11/2022      20/01/2023
# 2        B2CDevOps01                 14/11/2022      20/01/2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5878 entries, 0 to 5877
# Data columns (total 18 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contact Name                             5878 non-null   object
#  1   Contact: Gender                          5878 non-null   object
#  2   LMS Id                                   5878 non-null   float64
#  3   Course Connection: Course Connection ID  5878 non-null   object
#  4   Course Offering Name                     5878 non-null   object
#  5   Course Offering ID                       5878 non-null   object
#  6   Course Offering Start Date               5878 non-null   object
#  7   Course End Date                          5878 non-null   object
#  8   Attendance Score                         5878 non-null   float64
#  9   IP Grade Average                         5878 non-null   float64
# ...

# %%
df.isnull().sum()/len(df)*100
# Out:
# Contact Name                               0.0
# Contact: Gender                            0.0
# LMS Id                                     0.0
# Course Connection: Course Connection ID    0.0
# Course Offering Name                       0.0
# Course Offering ID                         0.0
# Course Offering Start Date                 0.0
# Course End Date                            0.0
# Attendance Score                           0.0
# IP Grade Average                           0.0
# Total Canvas Hours                         0.0
# Contact: Student Overall NPS               0.0
# Contact: Student SIS ID                    0.0
# Contact: Contact ID                        0.0
# Course Term                                0.0
# Highest education level completed          0.0
# Applicant Conversion Probability           0.0
# Applicant: Contact ID                      0.0
# dtype: float64

# %%
# Contact: Contact ID
# Applicant: Contact ID
# join dataset

# %% [markdown]
# Objectives
#
# 1. Understand  the relationship between NPS and the level of education
# 2. What is the conversion probability, the average conversion between admission and classroom.
# 3. How various education level influence performance.
# 4. Identify if data favors DevOps, product design, and cyber security and work on the objective.

# %%
# Objective 1
# 1.Understand the relationship between NPS and the level of education

df.head()
# Out:
#         Contact Name Contact: Gender   LMS Id  \
# 0      Rodney Kabiru            Male  35797.0
# 1     Jeffery Omondi            Male  35800.0
# 2     Jeffery Omondi            Male  35800.0
# 3  Maamun Bwanakombo            Male     63.0
# 4       Sandra Metto          Female     47.0
#
#   Course Connection: Course Connection ID Course Offering Name  \
# 0                                CC-50735          B2CDevOps01
# 1                                CC-50753          B2CDevOps01
# 2                                CC-50753          B2CDevOps01
# 3                                CC-58097          B2CDevOps02
# 4                                CC-58105          B2CDevOps02
#
#   Course Offering ID Course Offering Start Date Course End Date  \
# 0        B2CDevOps01                 14/11/2022      20/01/2023
# 1        B2CDevOps01                 14/11/2022      20/01/2023
# 2        B2CDevOps01                 14/11/2022      20/01/2023
# ...

# %%
df.columns
# Out:
# Index(['Contact Name', 'Contact: Gender', 'LMS Id',
#        'Course Connection: Course Connection ID', 'Course Offering Name',
#        'Course Offering ID', 'Course Offering Start Date', 'Course End Date',
#        'Attendance Score', 'IP Grade Average', 'Total Canvas Hours',
#        'Contact: Student Overall NPS', 'Contact: Student SIS ID',
#        'Contact: Contact ID', 'Course Term',
#        'Highest education level completed', 'Applicant Conversion Probability',
#        'Applicant: Contact ID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5878 entries, 0 to 5877
# Data columns (total 18 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contact Name                             5878 non-null   object
#  1   Contact: Gender                          5878 non-null   object
#  2   LMS Id                                   5878 non-null   float64
#  3   Course Connection: Course Connection ID  5878 non-null   object
#  4   Course Offering Name                     5878 non-null   object
#  5   Course Offering ID                       5878 non-null   object
#  6   Course Offering Start Date               5878 non-null   object
#  7   Course End Date                          5878 non-null   object
#  8   Attendance Score                         5878 non-null   float64
#  9   IP Grade Average                         5878 non-null   float64
# ...

# %%
plt.figure(figsize=(7, 4))
plt.xticks(rotation=75)
sns.barplot(data=df, x='Highest education level completed', y='Contact: Student Overall NPS')
# Out:
# <Axes: xlabel='Highest education level completed', ylabel='Contact: Student Overall NPS'>

# %%
plt.figure(figsize=(7, 4))
plt.xticks(rotation=75)
sns.boxplot(data=df, x='Highest education level completed', y='Contact: Student Overall NPS')
# Out:
# <Axes: xlabel='Highest education level completed', ylabel='Contact: Student Overall NPS'>

# %%
plt.figure(figsize=(7, 4))
plt.xticks(rotation=75)
sns.histplot(data=df, x='Highest education level completed', y='Contact: Student Overall NPS')
# Out:
# <Axes: xlabel='Highest education level completed', ylabel='Contact: Student Overall NPS'>

# %%
sns.histplot(df['Contact: Student Overall NPS'], bins=30)
# Out:
# <Axes: xlabel='Contact: Student Overall NPS', ylabel='Count'>

# %%
cd.head()
# Out:
#       Contact Name Contact: Gender   LMS Id  \
# 16    Emma Gachoki          Female  35796.0
# 17  Evelyne Mwende          Female  35798.0
# 18   Jerry Auvagha            Male  35799.0
# 19    Peter Gakure            Male  35792.0
# 21    Felix Kinaro            Male  35802.0
#
#    Course Connection: Course Connection ID Course Offering Name  \
# 16                                CC-50732          B2CDevOps01
# 17                                CC-50749          B2CDevOps01
# 18                                CC-50727          B2CDevOps01
# 19                                CC-50755          B2CDevOps01
# 21                                CC-50738          B2CDevOps01
#
#    Course Offering ID Course Offering Start Date Course End Date  \
# 16        B2CDevOps01                 14/11/2022      20/01/2023
# 17        B2CDevOps01                 14/11/2022      20/01/2023
# 18        B2CDevOps01                 14/11/2022      20/01/2023
# ...

# %%
df.columns
# Out:
# Index(['Contact Name', 'Contact: Gender', 'LMS Id',
#        'Course Connection: Course Connection ID', 'Course Offering Name',
#        'Course Offering ID', 'Course Offering Start Date', 'Course End Date',
#        'Attendance Score', 'IP Grade Average', 'Total Canvas Hours',
#        'Contact: Student Overall NPS', 'Contact: Student SIS ID',
#        'Contact: Contact ID', 'Course Term',
#        'Highest education level completed', 'Applicant Conversion Probability',
#        'Applicant: Contact ID'],
#       dtype='object')

# %%
# Objective 2
# What is the conversion probability, the average conversion between admission and classroom.
admission_count = cd['Course Connection: Course Connection ID'].nunique()
classroom_count =cd['Course Offering Name'].nunique()
conversion_probability=classroom_count/admission_count
print(f"conversion probability is:{conversion_probability:.2f}")
# Out:
# conversion probability is:0.02

# %%
print(f"The average conversion is:{cd.groupby('Course Connection: Course Connection ID')['Course Offering Name'].nunique().mean()}")
# Out:
# The average conversion is:1.0

# %%
# Objective3
# How various education level influence performance.
df.head()
# Out:
#         Contact Name Contact: Gender   LMS Id  \
# 0      Rodney Kabiru            Male  35797.0
# 1     Jeffery Omondi            Male  35800.0
# 2     Jeffery Omondi            Male  35800.0
# 3  Maamun Bwanakombo            Male     63.0
# 4       Sandra Metto          Female     47.0
#
#   Course Connection: Course Connection ID Course Offering Name  \
# 0                                CC-50735          B2CDevOps01
# 1                                CC-50753          B2CDevOps01
# 2                                CC-50753          B2CDevOps01
# 3                                CC-58097          B2CDevOps02
# 4                                CC-58105          B2CDevOps02
#
#   Course Offering ID Course Offering Start Date Course End Date  \
# 0        B2CDevOps01                 14/11/2022      20/01/2023
# 1        B2CDevOps01                 14/11/2022      20/01/2023
# 2        B2CDevOps01                 14/11/2022      20/01/2023
# ...

# %%
df.to_csv("data.csv")
